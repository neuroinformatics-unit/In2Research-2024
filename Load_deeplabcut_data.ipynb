# %%
from pathlib import Path
from movement.io import load_poses

# %%
data_folder = Path(r"C:\Users\UCL053833\OneDrive\Desktop\Project\Data")
print(data_folder)
assert data_folder.is_dir()
# Out:
# C:\Users\UCL053833\OneDrive\Desktop\Project\Data

# %%
file_name = "220804_SB021_FM001_female2_2022-08-04-223620DLC_resnet50_shanice_allNov29shuffle1_196000_filtered.csv"
file_path = data_folder / file_name
print(file_path)
assert file_path.is_file()
# Out:
# C:\Users\UCL053833\OneDrive\Desktop\Project\Data\220804_SB021_FM001_female2_2022-08-04-223620DLC_resnet50_shanice_allNov29shuffle1_196000_filtered.csv

# %%
ds = load_poses.from_dlc_file(file_path, fps=50)

# %%
ds
# Out:
# <xarray.Dataset> Size: 9MB
# Dimensions:      (time: 18680, individuals: 1, keypoints: 20, space: 2)
# Coordinates:
#   * time         (time) float64 149kB 0.0 0.02 0.04 0.06 ... 373.5 373.6 373.6
#   * individuals  (individuals) <U12 48B 'individual_0'
#   * keypoints    (keypoints) <U22 2kB 'resident_nose' ... 'intruder_lowerback'
#   * space        (space) <U1 8B 'x' 'y'
# Data variables:
#     position     (time, individuals, keypoints, space) float64 6MB 1.273e+03 ...
#     confidence   (time, individuals, keypoints) float64 3MB 0.008848 ... 0.0
# Attributes:
#     fps:              50.0
#     time_unit:        seconds
#     source_software:  DeepLabCut
#     source_file:      C:/Users/UCL053833/OneDrive/Desktop/Project/Data/220804...

# %%
all_keypoints = ds.keypoints.values

# %%
print(all_keypoints)
# Out:
# ['resident_nose' 'resident_leftear' 'resident_rightear' 'resident_butt'
#  'resident_neck' 'resident_lefthip' 'resident_righthip'
#  'resident_leftshoulder' 'resident_rightshoulder' 'resident_lowerback'
#  'intruder_nose' 'intruder_leftear' 'intruder_rightear' 'intruder_butt'
#  'intruder_neck' 'intruder_lefthip' 'intruder_righthip'
#  'intruder_leftshoulder' 'intruder_rightshoulder' 'intruder_lowerback']

# %%
resident_keypoints = []
intruder_keypoints = []

for kp in all_keypoints:
    if kp.startswith("resident"):
        resident_keypoints.append(kp)
    else:
        intruder_keypoints.append(kp)
print(intruder_keypoints)
print(resident_keypoints)
# Out:
# ['intruder_nose', 'intruder_leftear', 'intruder_rightear', 'intruder_butt', 'intruder_neck', 'intruder_lefthip', 'intruder_righthip', 'intruder_leftshoulder', 'intruder_rightshoulder', 'intruder_lowerback']
# ['resident_nose', 'resident_leftear', 'resident_rightear', 'resident_butt', 'resident_neck', 'resident_lefthip', 'resident_righthip', 'resident_leftshoulder', 'resident_rightshoulder', 'resident_lowerback']
